# %%
import random

words = ['monkey',
 'shoe',
 'quartz',
 'rat',
 'glove',
 'face',
 'design',
 'cart',
 'way',
 'night',
 'size',
 'toes',
 'yard',
 'business',
 'street',
 'calendar',
 'screw',
 'pets',
 'place',
 'mailbox',
 'pies',
 'ocean',
 'achiever',
 'behavior',
 'rail',
 'crow',
 'ants',
 'hole',
 'animal',
 'advertisement',
 'cast',
 'error',
 'tree',
 'level',
 'quiver',
 'steam',
 'van',
 'current',
 'moon',
 'suggestion',
 'plane',
 'thread',
 'needle',
 'art',
 'sisters',
 'lip',
 'horse',
 'zipper',
 'waves',
 'airport',
 'pan',
 'kick',
 'stew',
 'icicle',
 'finger',
 'lamp',
 'wrist',
 'birthday',
 'attack',
 'rifle',
 'knife',
 'self',
 'fireman',
 'fear',
 'pickle',
 'ticket',
 'turkey',
 'crown',
 'market',
 'skin',
 'note',
 'parcel',
 'view',
 'daughter',
 'town',
 'territory',
 'quiet',
 'gun',
 'desire',
 'brother',
 'rabbits',
 'coach',
 'judge',
 'hate',
 'plantation',
 'belief',
 'friction',
 'crayon',
 'powder',
 'engine',
 'hook',
 'bushes',
 'bag',
 'volleyball',
 'wing',
 'swing',
 'treatment',
 'guide',
 'space',
 'appliance']

def generate_word():
    return random.choice(words)
